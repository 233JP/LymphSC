# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_csv('./source/bbbp.csv',sep=',')
print(len(data))
data
# Out:
# 2050
#        num                               name  p_np  \
# 0        1                         Propanolol     1
# 1        2               Terbutylchlorambucil     1
# 2        3                              40730     1
# 3        4                                 24     1
# 4        5                        cloxacillin     1
# ...    ...                                ...   ...
# 2045  2049                         licostinel     1
# 2046  2050  ademetionine(adenosyl-methionine)     1
# 2047  2051                           mesocarb     1
# 2048  2052                         tofisoline     1
# 2049  2053                      azidamfenicol     1
#
#                                                  smiles
# 0                      [Cl].CC(C)NCC(O)COc1cccc2ccccc12
# 1              C(=O)(OC(C)(C)C)CCCc1ccc(cc1)N(CCCl)CCCl
# 2     c12c3c(N4CCN(C)CC4)c(F)cc1c(c(C(O)=O)cn2C(C)CO...
# 3                      C1CCN(CC1)Cc1cccc(c1)OCCCNC(=O)C
# 4     Cc1onc(c2ccccc2Cl)c1C(=O)N[C@H]3[C@H]4SC(C)(C)...
# ...                                                 ...
# 2045    C1=C(Cl)C(=C(C2=C1NC(=O)C(N2)=O)[N+](=O)[O-])Cl
# 2046  [C@H]3([N]2C1=C(C(=NC=N1)N)N=C2)[C@@H]([C@@H](...
# 2047  [O+]1=N[N](C=C1[N-]C(NC2=CC=CC=C2)=O)C(CC3=CC=...
# 2048  C1=C(OC)C(=CC2=C1C(=[N+](C(=C2CC)C)[NH-])C3=CC...
# 2049  [N+](=NCC(=O)N[C@@H]([C@H](O)C1=CC=C([N+]([O-]...
#
# [2050 rows x 4 columns]

# %%
import rdkit
from rdkit import Chem
from rdkit.Chem import AllChem
from tqdm import tqdm_notebook

# cal the atom num
data_smiles = data['smiles'].values.tolist()
distributions = np.zeros(11)
max_length = -1
for smile in data_smiles:
    mol = Chem.MolFromSmiles(smile)
    try:
        Chem.SanitizeMol(mol)
    except:
        continue
    atom_num = mol.GetNumAtoms() // 10
    if atom_num < 10:
        distributions[atom_num] += 1
    else:
        distributions[-1] += 1
    max_length = mol.GetNumAtoms() if mol.GetNumAtoms() > max_length else max_length

for i in range(11):
    if i < 10:
        print(f'{i*10} - {(i+1) * 10}: {distributions[i]}')
    else:
        print(f'> {i * 10}: {distributions[i]}')
print(f'max length: {max_length}')
print(f'source: {len(data_smiles)}, after sanitize: {np.sum(distributions)}')
# import numpy as np
# from rdkit import Chem

# data_smiles = data['smiles'].values.tolist()
# distributions = np.zeros(11)
# max_length = -1

# for smile in data_smiles:
#     mol = Chem.MolFromSmiles(smile)
#     if mol is None:
#         continue
#     try:
#         Chem.SanitizeMol(mol)
#     except (ValueError, Chem.AtomValenceException, Chem.KekulizeException) as e:
#         print(f"Sanitization error for SMILES {smile}: {e}")
#         continue

#     atom_num = mol.GetNumAtoms() // 10
#     if atom_num < 10:
#         distributions[atom_num] += 1
#     else:
#         distributions[-1] += 1
#     max_length = max(max_length, mol.GetNumAtoms())

# for i in range(11):
#     if i < 10:
#         print(f'{i*10} - {(i+1) * 10}: {distributions[i]}')
#     else:
#         print(f'> {i * 10}: {distributions[i]}')

# print(f'max length: {max_length}')
# print(f'source: {len(data_smiles)}, after sanitize: {np.sum(distributions)}')
# Out:
# [13:08:05] Explicit valence for atom # 1 N, 4, is greater than permitted
# [13:08:05] WARNING: not removing hydrogen atom without neighbors
# [13:08:05] Explicit valence for atom # 6 N, 4, is greater than permitted
# [13:08:05] WARNING: not removing hydrogen atom without neighbors
# [13:08:05] WARNING: not removing hydrogen atom without neighbors
# [13:08:05] WARNING: not removing hydrogen atom without neighbors
# [13:08:05] WARNING: not removing hydrogen atom without neighbors
# [13:08:05] WARNING: not removing hydrogen atom without neighbors
# [13:08:05] WARNING: not removing hydrogen atom without neighbors
# [13:08:05] Explicit valence for atom # 6 N, 4, is greater than permitted
# [13:08:05] WARNING: not removing hydrogen atom without neighbors
# [13:08:05] WARNING: not removing hydrogen atom without neighbors
# [13:08:05] WARNING: not removing hydrogen atom without neighbors
# [13:08:05] WARNING: not removing hydrogen atom without neighbors
# [13:08:05] Explicit valence for atom # 11 N, 4, is greater than permitted
# [13:08:05] Explicit valence for atom # 12 N, 4, is greater than permitted
# [13:08:05] Explicit valence for atom # 5 N, 4, is greater than permitted
# [13:08:05] Explicit valence for atom # 5 N, 4, is greater than permitted
# [13:08:05] Explicit valence for atom # 5 N, 4, is greater than permitted
# [13:08:05] Explicit valence for atom # 5 N, 4, is greater than permitted
# [13:08:05] Explicit valence for atom # 5 N, 4, is greater than permitted
# [13:08:05] WARNING: not removing hydrogen atom without neighbors
# [13:08:05] WARNING: not removing hydrogen atom without neighbors
# [13:08:05] Explicit valence for atom # 5 N, 4, is greater than permitted
# [13:08:05] WARNING: not removing hydrogen atom without neighbors
# [13:08:05] WARNING: not removing hydrogen atom without neighbors
# [13:08:05] WARNING: not removing hydrogen atom without neighbors
# [13:08:05] WARNING: not removing hydrogen atom without neighbors
# [13:08:05] WARNING: not removing hydrogen atom without neighbors
# [13:08:05] WARNING: not removing hydrogen atom without neighbors
# [13:08:05] WARNING: not removing hydrogen atom without neighbors
# [13:08:05] WARNING: not removing hydrogen atom without neighbors
# [13:08:05] WARNING: not removing hydrogen atom without neighbors
# [13:08:05] WARNING: not removing hydrogen atom without neighbors
# [13:08:05] WARNING: not removing hydrogen atom without neighbors
# [13:08:05] WARNING: not removing hydrogen atom without neighbors
# [13:08:05] WARNING: not removing hydrogen atom without neighbors
# [13:08:05] WARNING: not removing hydrogen atom without neighbors
# 0 - 10: 78.0
# 10 - 20: 557.0
# 20 - 30: 961.0
# 30 - 40: 345.0
# 40 - 50: 46.0
# 50 - 60: 30.0
# 60 - 70: 11.0
# 70 - 80: 3.0
# 80 - 90: 3.0
# 90 - 100: 1.0
# > 100: 4.0
# max length: 132
# source: 2050, after sanitize: 2039.0
# [13:08:05] WARNING: not removing hydrogen atom without neighbors
# [13:08:05] WARNING: not removing hydrogen atom without neighbors
# [13:08:05] WARNING: not removing hydrogen atom without neighbors
# [13:08:05] WARNING: not removing hydrogen atom without neighbors
# [13:08:05] WARNING: not removing hydrogen atom without neighbors
# [13:08:05] WARNING: not removing hydrogen atom without neighbors
# [13:08:05] WARNING: not removing hydrogen atom without neighbors
# [13:08:05] WARNING: not removing hydrogen atom without neighbors
# [13:08:05] WARNING: not removing hydrogen atom without neighbors
# [13:08:05] WARNING: not removing hydrogen atom without neighbors
# [13:08:05] WARNING: not removing hydrogen atom without neighbors
# [13:08:05] WARNING: not removing hydrogen atom without neighbors
# [13:08:05] WARNING: not removing hydrogen atom without neighbors

# %%
# import rdkit
# from rdkit import Chem
# from rdkit.Chem import AllChem
# from tqdm import tqdm_notebook

# element_dict = {}

# data_smiles = data['smiles'].values.tolist()
# data_labels = data['p_np'].values.tolist()
# data_san_mol, data_san_label = [],[]
# for smile,label in tqdm_notebook(zip(data_smiles, data_labels), total=len(data_smiles)):
#     mol = Chem.MolFromSmiles(smile)
    
#     # check the sanitizemol
#     try:
#         Chem.SanitizeMol(mol)
#     except:
#         continue
        
#     if mol.GetNumAtoms() >= 100:
#         continue
        
#     data_san_mol.append(mol)
#     data_san_label.append(label)
    
#     for atom in mol.GetAtoms():
#         element_dict[atom.GetSymbol()] = atom.GetAtomicNum()

import numpy as np
from rdkit import Chem
from tqdm.notebook import tqdm

element_dict = {}

data_smiles = data['smiles'].values.tolist()
data_labels = data['p_np'].values.tolist()
data_san_mol, data_san_label = [], []

for smile, label in tqdm(zip(data_smiles, data_labels), total=len(data_smiles)):
    mol = Chem.MolFromSmiles(smile)
    if mol is None:
        continue

    # 检查SanitizeMol
    try:
        Chem.SanitizeMol(mol)
    except (ValueError, Chem.AtomValenceException) as e:
        print(f"Sanitization error for SMILES {smile}: {e}")
        continue

    if mol.GetNumAtoms() >= 100:
        continue

    data_san_mol.append(mol)
    data_san_label.append(label)

    for atom in mol.GetAtoms():
        element_dict[atom.GetSymbol()] = atom.GetAtomicNum()

# 输出元素字典以供检查
print(element_dict)
# Out:
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=2050.0), HTML(value='')))
# [13:08:06] Explicit valence for atom # 1 N, 4, is greater than permitted
# [13:08:06] WARNING: not removing hydrogen atom without neighbors
# [13:08:06] Explicit valence for atom # 6 N, 4, is greater than permitted
# [13:08:06] WARNING: not removing hydrogen atom without neighbors
# [13:08:06] WARNING: not removing hydrogen atom without neighbors
# [13:08:06] WARNING: not removing hydrogen atom without neighbors
# [13:08:06] WARNING: not removing hydrogen atom without neighbors
# [13:08:06] WARNING: not removing hydrogen atom without neighbors
# [13:08:06] WARNING: not removing hydrogen atom without neighbors
# [13:08:06] Explicit valence for atom # 6 N, 4, is greater than permitted
# [13:08:06] WARNING: not removing hydrogen atom without neighbors
# [13:08:06] WARNING: not removing hydrogen atom without neighbors
# [13:08:06] WARNING: not removing hydrogen atom without neighbors
# [13:08:06] WARNING: not removing hydrogen atom without neighbors
# [13:08:06] Explicit valence for atom # 11 N, 4, is greater than permitted
# [13:08:06] Explicit valence for atom # 12 N, 4, is greater than permitted
# [13:08:06] Explicit valence for atom # 5 N, 4, is greater than permitted
# [13:08:06] Explicit valence for atom # 5 N, 4, is greater than permitted
# [13:08:06] Explicit valence for atom # 5 N, 4, is greater than permitted
# [13:08:06] Explicit valence for atom # 5 N, 4, is greater than permitted
# [13:08:06] Explicit valence for atom # 5 N, 4, is greater than permitted
# [13:08:06] WARNING: not removing hydrogen atom without neighbors
# [13:08:06] WARNING: not removing hydrogen atom without neighbors
# [13:08:06] Explicit valence for atom # 5 N, 4, is greater than permitted
# [13:08:06] WARNING: not removing hydrogen atom without neighbors
# [13:08:06] WARNING: not removing hydrogen atom without neighbors
# [13:08:06] WARNING: not removing hydrogen atom without neighbors
# [13:08:06] WARNING: not removing hydrogen atom without neighbors
# [13:08:06] WARNING: not removing hydrogen atom without neighbors
# [13:08:06] WARNING: not removing hydrogen atom without neighbors
# [13:08:06] WARNING: not removing hydrogen atom without neighbors
# [13:08:06] WARNING: not removing hydrogen atom without neighbors
# [13:08:06] WARNING: not removing hydrogen atom without neighbors
# [13:08:06] WARNING: not removing hydrogen atom without neighbors
# [13:08:06] WARNING: not removing hydrogen atom without neighbors
# [13:08:06] WARNING: not removing hydrogen atom without neighbors
# [13:08:06] WARNING: not removing hydrogen atom without neighbors
# [13:08:06] WARNING: not removing hydrogen atom without neighbors
# [13:08:06] WARNING: not removing hydrogen atom without neighbors
# [13:08:06] WARNING: not removing hydrogen atom without neighbors
# [13:08:06] WARNING: not removing hydrogen atom without neighbors
# [13:08:06] WARNING: not removing hydrogen atom without neighbors
# [13:08:06] WARNING: not removing hydrogen atom without neighbors
# [13:08:06] WARNING: not removing hydrogen atom without neighbors
# [13:08:06] WARNING: not removing hydrogen atom without neighbors
# [13:08:06] WARNING: not removing hydrogen atom without neighbors
# [13:08:06] WARNING: not removing hydrogen atom without neighbors
# [13:08:06] WARNING: not removing hydrogen atom without neighbors
# [13:08:06] WARNING: not removing hydrogen atom without neighbors
# {'Cl': 17, 'C': 6, 'N': 7, 'O': 8, 'F': 9, 'S': 16, 'Br': 35, 'I': 53, 'H': 1, 'Na': 11, 'P': 15, 'Ca': 20, 'B': 5}
# [13:08:06] WARNING: not removing hydrogen atom without neighbors
# [13:08:06] WARNING: not removing hydrogen atom without neighbors

# %%
print(len(data_san_mol), len(data_san_label))
print(element_dict)
# Out:
# 2035 2035
# {'Cl': 17, 'C': 6, 'N': 7, 'O': 8, 'F': 9, 'S': 16, 'Br': 35, 'I': 53, 'H': 1, 'Na': 11, 'P': 15, 'Ca': 20, 'B': 5}

# %%
# Check list order
for idx,(mol,label) in enumerate(zip(data_san_mol, data_san_label)):
    print(idx, Chem.MolToSmiles(mol), label)
    if idx >= 100:
        break
print()
max_length = max([mol.GetNumAtoms() for mol in data_san_mol])
print("max length is {}".format(max_length))
# Out:
# 0 CC(C)NCC(O)COc1cccc2ccccc12.[Cl] 1
# 1 CC(C)(C)OC(=O)CCCc1ccc(N(CCCl)CCCl)cc1 1
# 2 CC1COc2c(N3CCN(C)CC3)c(F)cc3c(=O)c(C(=O)O)cn1c23 1
# 3 CC(=O)NCCCOc1cccc(CN2CCCCC2)c1 1
# 4 Cc1onc(-c2ccccc2Cl)c1C(=O)N[C@@H]1C(=O)N2[C@@H](C(=O)O)C(C)(C)S[C@H]12 1
# 5 CCN1CCN(C(=O)N[C@@H](C(=O)N[C@@H]2C(=O)N3C(C(=O)O)=C(CSc4nnnn4C)CS[C@H]23)c2ccc(O)cc2)C(=O)C1=O 1
# 6 CN(C)[C@@H]1C(=O)/C(=C(/O)NCN2CCCC2)C(=O)[C@@]2(O)C(=O)C3=C(O)c4c(O)cccc4[C@@](C)(O)[C@H]3C[C@@H]12 1
# 7 Cc1nccn1CC1CCc2c(c3ccccc3n2C)C1=O 1
# 8 COc1ccc([C@@H]2Sc3ccccc3N(CCN(C)C)C(=O)[C@@H]2OC(C)=O)cc1 1
# 9 NC(N)=NC(=O)c1nc(Cl)c(N)nc1N 1
# 10 CN1Cc2c(-c3noc(C(C)(O)CO)n3)ncn2-c2cccc(Cl)c2C1=O 0
# 11 Cc1cn([C@H]2C[C@H](F)[C@@H](CO)O2)c(=O)[nH]c1=O 1
# 12 ClCCl 1
# 13 CC(C)(C)NC(=O)C1CC2CCCCC2CN1CC(O)C(Cc1ccccc1)NC(=O)C(CC(N)=O)NC(=O)c1ccc2ccccc2n1 1
# 14 CCC(=O)C(CC(C)N(C)C)(c1ccccc1)c1ccccc1 1
# 15 CCC(=O)N(c1ccccc1)C1(COC)CCN(CCn2nnn(CC)c2=O)CC1 1
# 16 CN(C)C(=O)C(CCN1CCC(O)(c2ccc(Cl)cc2)CC1)(c1ccccc1)c1ccccc1 1
# 17 CN1C2CCC1CC(OC(=O)[C@H](CO)c1ccccc1)C2 1
# 18 COc1ccc(Cl)cc1C(=O)NCCc1ccc(S(=O)(=O)NC(=O)NC2CCCCC2)cc1 1
# 19 Nc1nnc(-c2cccc(Cl)c2Cl)c(N)n1 1
# 20 CCCC(C)C 1
# 21 C[C@H](N)Cc1ccccc1 1
# 22 CN(C)Cc1ccc(CSCCNc2nc(=O)c(Cc3ccc4ccccc4c3)c[nH]2)o1 0
# 23 CC(C)(C)NCC(O)COc1cccc2c1C[C@H](O)[C@H](O)C2 1
# 24 CCC(=O)N(c1ccccc1)C1(COC)CCN(CCc2cccs2)CC1 1
# 25 CCNC(=NC#N)NCCSCc1ncccc1Br 0
# 26 Cc1ccc(-c2nc3ccc(C)cn3c2CC(=O)N(C)C)cc1 1
# 27 CN1CCN(C2=c3ccccc3=Nc3ccc(Cl)cc3N2)CC1 1
# 28 FC(F)(F)c1ccc(N2CCNCC2)nc1Cl 1
# 29 CCN1CCN(C(=O)N[C@@H](C(=O)N[C@@H]2C(=O)N3[C@@H](C(=O)O)C(C)(C)S[C@H]23)c2ccccc2)C(=O)C1=O.O 1
# 30 CCCC(C)C1(CC)C(=O)NC(=O)NC1=O 1
# 31 C[C@H]1COc2c(N3CCN(C)CC3)c(F)cc3c(=O)c(C(=O)O)cn1c23 1
# 32 O=C(NCCCOc1cccc(CN2CCCCC2)c1)c1ccccc1 1
# 33 CN1Cc2c(C(=O)OC(C)(C)C)ncn2-c2ccsc2C1=O 1
# 34 CCC(=O)N(c1ccccc1)C1CCN(CCc2ccccc2)CC1 1
# 35 CCOC(=O)c1cncn1C(C)c1ccccc1 1
# 36 CN(C)c1cc(-c2nc(N)n[nH]2)ccn1 0
# 37 CN1CCN(CCCN2c3ccccc3Sc3ccc(Cl)cc32)CC1 1
# 38 Nc1ccc(-c2nc3ccc(O)cc3s2)cc1I 1
# 39 CC(=O)Nc1cccc(-c2csc(N=C(N)N)n2)c1 0
# 40 CN1[C@H]2CCC[C@@H]1CC(NC(=O)c1nn(C)c3ccccc13)C2 1
# 41 CS(=O)(=O)c1ccc([C@@H](O)[C@@H](CO)NC(=O)C(Cl)Cl)cc1 1
# 42 NC(N)=Nc1nc(-c2ccccc2)cs1 1
# 43 Cc1cccc(C)c1OCC(C)N 1
# 44 CCC(=O)O[C@](Cc1ccccc1)(c1ccccc1)[C@H](C)CN(C)C 1
# 45 CNCCCN1c2ccccc2Sc2ccc(Cl)cc21 1
# 46 CN(C)Cc1ccc(-c2cccc(NC3N=CC=C3[N+](=O)[O-])c2)o1 1
# 47 Cn1nnnc1SCC1=C(C(=O)O)N2C(=O)[C@@H](NC(=O)[C@H](O)c3ccccc3)[C@H]2SC1 1
# 48 CN(C)CCc1ccccn1 1
# 49 O=C1CCCN1CCCCN1CCN(c2cc(C(F)(F)F)ccn2)CC1 1
# 50 C=C[C@H]1CN2CC[C@H]1C[C@@H]2[C@@H](O)c1ccnc2ccc(OC)cc12 1
# 51 CCc1ccccc1 1
# 52 NC(N)=Nc1nc(-c2cccc(N)c2)cs1 1
# 53 CC[C@]1(O)C[C@H]2CN(CCc3c([nH]c4ccccc34)[C@@](C(=O)OC)(c3cc4c(cc3OC)N(C)[C@H]3[C@@](O)(C(=O)OC)[C@H](OC(C)=O)[C@]5(CC)C=CCN6CC[C@]43[C@@H]65)C2)C1 1
# 54 CCCC(=O)Nc1ccc(OCC(O)CNC(C)C)c(C(C)=O)c1 1
# 55 NCCCN1c2ccccc2Sc2ccc(Cl)cc21 1
# 56 CN(C)Cc1ccc(CSCCNc2[nH]cc(Cc3ccccc3)c2[N+](=O)[O-])o1 1
# 57 CNC(=NC#N)Nc1cccc(-c2csc(N=C(N)N)n2)c1 0
# 58 CNCCc1ccccn1 1
# 59 CN[C@H]1CC[C@@H](c2ccc(Cl)c(Cl)c2)c2ccccc21.[Cl-].[H+] 1
# 60 CC[C@]1(O)C[C@H]2CN(CCc3c([nH]c4ccccc34)[C@@](C(=O)OC)(c3cc4c(cc3OC)N(C=O)[C@H]3[C@@](O)(C(=O)OC)[C@H](OC(C)=O)[C@]5(CC)C=CCN6CC[C@]43[C@@H]65)C2)C1 1
# 61 CCC(NC(=O)c1c(C)c(-c2ccccc2)nc2ccccc12)c1ccccc1 1
# 62 O=S(=O)(c1ccc2cc[nH]c2c1)N1CCCC1CCN1CCC(Oc2cccc(Cl)c2)CC1 1
# 63 CN(C)Cc1ccnc(-c2cccc(NC3N=CC=C3[N+](=O)[O-])c2)c1 1
# 64 CNCCCC12CCC(c3ccccc31)c1ccccc12 1
# 65 c1cc(CN2CCCCC2)cc(OCCCNc2nccs2)c1 1
# 66 CN1Cc2c(-c3noc(C(C)(C)O)n3)ncn2-c2cccc(Cl)c2C1=O 0
# 67 CO/N=C(\C(=O)N[C@H]1C(=O)N2C(C(=O)[O-])=C(COC(C)=O)CS[C@@H]12)c1csc(N)n1.[Na+] 1
# 68 NC(=O)N1c2ccccc2C2OC2c2ccccc21 1
# 69 C1CCCCC1 1
# 70 Cc1csc(N=C(N)N)n1 1
# 71 CCCN(CCC)CCc1ccc(O)c2c1CC(=O)N2 1
# 72 CN1CC2c3ccccc3Oc3ccc(Cl)cc3C2C1 1
# 73 CN(C)Cc1ccc(CSCCNC2N=CC=C2[N+](=O)[O-])o1 0
# 74 CO/N=C(\C(=O)N[C@@H]1C(=O)N2C(C(=O)O)=C(COC(N)=O)CS[C@H]12)c1ccco1 1
# 75 c1cc(CN2CCCCC2)cc(OCCCNc2nc3ccccc3o2)c1 1
# 76 Cc1cccc2c1Oc1ccccc1C1(O)CCN(C)CC21 1
# 77 O=[N+]([O-])C1=CC=NC1NCCSCc1ccccn1 1
# 78 CCCSc1ccc2[nH]c(NC(=O)OC)nc2c1 1
# 79 NCCc1cn2ccccc2n1 0
# 80 Cc1ncc([N+](=O)[O-])n1CC(O)CCl 1
# 81 CCCN(CCC)CCc1cccc2c1CC(=O)N2 1
# 82 Clc1ccc2c(c1)C1CNCC1c1ccccc1O2 1
# 83 CN(C)CCC=C1c2ccccc2CCc2ccccc21 1
# 84 CO/N=C(\C(=O)N[C@@H]1C(=O)N2C(C(=O)O)=C(CSc3nc(=O)c(=O)[nH]n3C)CS[C@H]12)c1csc(N)n1 1
# 85 c1ccc(NCCCOc2cccc(CN3CCCCC3)c2)nc1 1
# 86 Cc1cccc2c1Oc1ccccc1C1(O)CCNCC21 1
# 87 O=[N+]([O-])C1=CC=NC1NCCSCc1ncccc1Br 1
# 88 COc1cc2c(c(OC)c1OC)-c1ccc(OC)c(=O)cc1C(NC(C)=O)CC2 1
# 89 OCCCOc1cccc(CN2CCCCC2)c1 1
# 90 Cc1ncsc1CCCl 1
# 91 CCN(CC)C(=O)Nc1ccc(OCC(O)CNC(C)(C)C)c(C(C)=O)c1 1
# 92 FC(F)(F)CCl 1
# 93 CC(C)c1nc(-c2ncn3c2CN(C)C(=O)c2c(Cl)cccc2-3)no1 1
# 94 CO[C@@]1(NC(=O)Cc2cccs2)C(=O)N2C(C(=O)O)=C(COC(N)=O)CS[C@@H]21 1
# 95 C=CCC(N)c1ccccc1-c1noc2ccccc12 1
# 96 Cc1nc2n(c(=O)c1CCN1CCC(c3noc4cc(F)ccc34)CC1)CCCC2O 1
# 97 CC(=O)Nc1ccc(O)cc1 1
# 98 CC(=O)Oc1ccccc1C(=O)O 0
# 99 O=c1ncnc2[nH][nH]cc1-2 0
# 100 CCCCC[C@H](O)/C=C/[C@H]1[C@H](O)CC(=O)[C@@H]1CCCCCCC(=O)O 0
#
# max length is 90

# %%
# store as a pickle file
import pickle as pkl
with open('./preprocess/linba.pickle','wb') as fw:
    pkl.dump([data_san_mol, data_san_label],fw)

# %%
# read from pickle
import pickle as pkl
with open('./preprocess/linba.pickle','rb') as f:
    [data_san_mol, data_san_label] = pkl.load(f)
print(len(data_san_mol), len(data_san_label))
# Out:
# 2035 2035

# %%
# Out:
# # packages in environment at F:\WorkSoftware\Install\Anaconda3\envs\mole:
# #
# # Name                    Version                   Build  Channel
# aiohappyeyeballs          2.4.2                    pypi_0    pypi
# aiohttp                   3.10.6                   pypi_0    pypi
# aiosignal                 1.3.1                    pypi_0    pypi
# asttokens                 2.0.5              pyhd3eb1b0_0    anaconda
# async-timeout             4.0.3                    pypi_0    pypi
# attrs                     24.2.0                   pypi_0    pypi
# backcall                  0.2.0              pyhd3eb1b0_0    anaconda
# ca-certificates           2024.7.2             haa95532_0    anaconda
# certifi                   2024.8.30                pypi_0    pypi
# charset-normalizer        3.3.2                    pypi_0    pypi
# colorama                  0.4.6            py38haa95532_0    anaconda
# comm                      0.2.1            py38haa95532_0    anaconda
# debugpy                   1.6.7            py38hd77b12b_0    anaconda
# decorator                 5.1.1              pyhd3eb1b0_0    anaconda
# executing                 0.8.3              pyhd3eb1b0_0    anaconda
# filelock                  3.16.1                   pypi_0    pypi
# frozenlist                1.4.1                    pypi_0    pypi
# fsspec                    2024.9.0                 pypi_0    pypi
# huggingface-hub           0.25.1                   pypi_0    pypi
# idna                      3.10                     pypi_0    pypi
# importlib-metadata        7.0.1            py38haa95532_0    anaconda
# importlib_metadata        7.0.1                hd3eb1b0_0    anaconda
# ipykernel                 6.28.0           py38haa95532_0    anaconda
# ipython                   8.12.2           py38haa95532_0    anaconda
# jedi                      0.19.1           py38haa95532_0    anaconda
# jinja2                    3.1.4                    pypi_0    pypi
# joblib                    1.4.2                    pypi_0    pypi
# jupyter_client            8.6.0            py38haa95532_0    anaconda
# jupyter_core              5.7.2            py38haa95532_0    anaconda
# libffi                    3.4.4                hd77b12b_1    http://mirrors.tuna.tsinghua.edu.cn/anaconda/pkgs/main
# libsodium                 1.0.18               h62dcd97_0    anaconda
# markupsafe                2.1.5                    pypi_0    pypi
# matplotlib-inline         0.1.6            py38haa95532_0    anaconda
# mpmath                    1.3.0                    pypi_0    pypi
# multidict                 6.1.0                    pypi_0    pypi
# nest-asyncio              1.6.0            py38haa95532_0    anaconda
# networkx                  3.1                      pypi_0    pypi
# numpy                     1.24.4                   pypi_0    pypi
# openssl                   3.0.15               h827c3e9_0    anaconda
# packaging                 24.1             py38haa95532_0    anaconda
# pandas                    2.0.3                    pypi_0    pypi
# parso                     0.8.3              pyhd3eb1b0_0    anaconda
# pickleshare               0.7.5           pyhd3eb1b0_1003    anaconda
# pillow                    10.4.0                   pypi_0    pypi
# pip                       24.2             py38haa95532_0    http://mirrors.tuna.tsinghua.edu.cn/anaconda/pkgs/main
# platformdirs              3.10.0           py38haa95532_0    anaconda
# prompt-toolkit            3.0.43           py38haa95532_0    anaconda
# psutil                    6.0.0                    pypi_0    pypi
# pure_eval                 0.2.2              pyhd3eb1b0_0    anaconda
# pygments                  2.15.1           py38haa95532_1    anaconda
# pyparsing                 3.1.4                    pypi_0    pypi
# python                    3.8.19               h1aa4202_0    http://mirrors.tuna.tsinghua.edu.cn/anaconda/pkgs/main
# python-dateutil           2.9.0post0       py38haa95532_2    anaconda
# pytz                      2024.2                   pypi_0    pypi
# pywin32                   305              py38h2bbff1b_0    anaconda
# pyyaml                    6.0.2                    pypi_0    pypi
# pyzmq                     25.1.2           py38hd77b12b_0    anaconda
# rdkit                     2022.3.3                 pypi_0    pypi
# regex                     2024.9.11                pypi_0    pypi
# requests                  2.32.3                   pypi_0    pypi
# safetensors               0.4.5                    pypi_0    pypi
# scikit-learn              1.3.0                    pypi_0    pypi
# scipy                     1.10.1                   pypi_0    pypi
# setuptools                75.1.0           py38haa95532_0    http://mirrors.tuna.tsinghua.edu.cn/anaconda/pkgs/main
# six                       1.16.0             pyhd3eb1b0_1    anaconda
# sqlite                    3.45.3               h2bbff1b_0    http://mirrors.tuna.tsinghua.edu.cn/anaconda/pkgs/main
# stack_data                0.2.0              pyhd3eb1b0_0    anaconda
# sympy                     1.13.3                   pypi_0    pypi
# threadpoolctl             3.5.0                    pypi_0    pypi
# tokenizers                0.13.3                   pypi_0    pypi
# torch                     2.4.1                    pypi_0    pypi
# torch-geometric           2.6.1                    pypi_0    pypi
# tornado                   6.4.1            py38h827c3e9_0    anaconda
# tqdm                      4.52.0                   pypi_0    pypi
# traitlets                 5.14.3           py38haa95532_0    anaconda
# transformers              4.31.0                   pypi_0    pypi
# typing-extensions         4.12.2                   pypi_0    pypi
# typing_extensions         4.11.0           py38haa95532_0    anaconda
# tzdata                    2024.2                   pypi_0    pypi
# urllib3                   2.2.3                    pypi_0    pypi
# vc                        14.40                h2eaa2aa_1    http://mirrors.tuna.tsinghua.edu.cn/anaconda/pkgs/main
# vs2015_runtime            14.40.33807          h98bb1dd_1    http://mirrors.tuna.tsinghua.edu.cn/anaconda/pkgs/main
# wcwidth                   0.2.5              pyhd3eb1b0_0    anaconda
# wheel                     0.44.0           py38haa95532_0    http://mirrors.tuna.tsinghua.edu.cn/anaconda/pkgs/main
# yarl                      1.13.0                   pypi_0    pypi
# zeromq                    4.3.5                hd77b12b_0    anaconda
# zipp                      3.17.0           py38haa95532_0    anaconda
